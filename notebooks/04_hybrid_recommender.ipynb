# %% [markdown]
# # Hybrid Recommender System
#
# This notebook demonstrates the hybrid recommender that combines collaborative filtering and content-based filtering.

# %%
import pandas as pd
import sys
import os

# Add project root to path
project_root = os.path.join('..')
sys.path.insert(0, project_root)

from src.data.data_loader import DataLoader
from src.recommenders.hybrid_recommender import HybridRecommender
from src.evaluation.evaluator import RecommenderEvaluator
